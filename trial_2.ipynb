# %%
import gymnasium
import numpy as np
from gymnasium.spaces import Discrete, MultiDiscrete, Box, Dict
from gymnasium.utils import seeding

from pettingzoo import AECEnv
from pettingzoo.utils import AgentSelector, wrappers

# %%
class farmer():

    def __init__(self, farm_size,soil_quality, crop_preference, input_preference, risk_preference):
        self.farm_size=farm_size
        #Complete
        #crop and input preferences are dicts. soil quality, risk preference is float [0,1]. farm size is int [1,10]
        self.previous_crop_choices #add

    


    def update_contracts_offered():
        #Take the contracts offered by the agg and update in observation space.
        pass

    def action_spaces():
        #Contract accepted-> one hot over possible contracts+no contract
        #crop choice which is a softmax over the crop preference dict
        #input preference which is a softmax over the inpuit preference dict
        #tillage choice, between 0,1
        #These should all be gym spaces
    def reward():
        #Profit -lambda risk

# %%
class aggregator():

    def __init__(self, budget):
        self.budget=budget
        self.previous_contracts_accepted={}
        self.previous_profits={}
    
    def get_observations(farmers):
        #For each farmer get a dict of farm size, soil quality and previous crop history.
        pass

    def action_space():
        #Should be three contracts, one action based one result based one hybrid.
        #Action based: offer partial upfront payment for each measure taken , then full payment after verification that the measure has been taken.
        #Result based: offer payment only based on how much carbon is sequestered, after MRV at the end of the period.
        #Hybrid based: offer upfront payment for each measure taken, and additional payment after measuring how much carbon has actually been sequestered.
        pass

    def reward():
        #profit +lambda*carbon_sequestered
